# %%
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
from PIL import Image
model = YOLO("yolo26n.pt")
img = Image.open("data/animals/cow/OIP-0_QS9F_3tU65pqSudWhPEAHaE8.jpeg")
plt.imshow(img)
plt.axis('off')
plt.show()

results = model("data/animals/cow/OIP-0_QS9F_3tU65pqSudWhPEAHaE8.jpeg")
annotated = results[0].plot()
plt.imshow(annotated)
plt.axis("off")
# Out:
# image 1/1 /home/primel/PycharmProjects/pytorch/data/animals/cow/OIP-0_QS9F_3tU65pqSudWhPEAHaE8.jpeg: 448x640 5 cows, 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)
# (np.float64(-0.5), np.float64(299.5), np.float64(199.5), np.float64(-0.5))

# %%
results[0].boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([19., 19., 19., 19., 19.], device='cuda:0')
# conf: tensor([0.9182, 0.9013, 0.8921, 0.8758, 0.8101], device='cuda:0')
# data: tensor([[206.3911, 125.2405, 269.8947, 179.4643,   0.9182,  19.0000],
#         [147.0063, 113.9923, 198.7936, 167.1640,   0.9013,  19.0000],
#         [ 94.4331, 103.6100, 137.0963, 154.5189,   0.8921,  19.0000],
#         [ 14.5789,  79.2296,  67.7515, 143.7890,   0.8758,  19.0000],
#         [ 60.7452,  91.7330,  88.3022, 145.8761,   0.8101,  19.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (200, 300)
# shape: torch.Size([5, 6])
# xywh: tensor([[238.1429, 152.3524,  63.5036,  54.2238],
#         [172.9000, 140.5781,  51.7873,  53.1717],
#         [115.7647, 129.0644,  42.6632,  50.9089],
#         [ 41.1652, 111.5093,  53.1726,  64.5594],
#         [ 74.5237, 118.8046,  27.5570,  54.1431]], device='cuda:0')
# xywhn: tensor([[0.7938, 0.7618, 0.2117, 0.2711],
#         [0.5763, 0.7029, 0.1726, 0.2659],
#         [0.3859, 0.6453, 0.1422, 0.2545],
#         [0.1372, 0.5575, 0.1772, 0.3228],
#         [0.2484, 0.5940, 0.0919, 0.2707]], device='cuda:0')
# xyxy: tensor([[206.3911, 125.2405, 269.8947, 179.4643],
#         [147.0063, 113.9923, 198.7936, 167.1640],
#         [ 94.4331, 103.6100, 137.0963, 154.5189],
#         [ 14.5789,  79.2296,  67.7515, 143.7890],
#         [ 60.7452,  91.7330,  88.3022, 145.8761]], device='cuda:0')
# xyxyn: tensor([[0.6880, 0.6262, 0.8996, 0.8973],
#         [0.4900, 0.5700, 0.6626, 0.8358],
#         [0.3148, 0.5180, 0.4570, 0.7726],
#         [0.0486, 0.3961, 0.2258, 0.7189],
#         [0.2025, 0.4587, 0.2943, 0.7294]], device='cuda:0')
